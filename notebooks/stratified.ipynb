# %%
import pandas as pd

# %%
df = pd.read_csv("../input/train_folds.csv")

# %%
df.head(45)
# Out:
#     Unnamed: 0                                  path  int_nr_COTS  \
# 0            0   ../input/train_images/video_0/0.jpg            0
# 1            1   ../input/train_images/video_0/1.jpg            0
# 2            2   ../input/train_images/video_0/2.jpg            0
# 3            3   ../input/train_images/video_0/3.jpg            0
# 4            4   ../input/train_images/video_0/4.jpg            0
# 5            5   ../input/train_images/video_0/5.jpg            0
# 6            6   ../input/train_images/video_0/6.jpg            0
# 7            7   ../input/train_images/video_0/7.jpg            0
# 8            8   ../input/train_images/video_0/8.jpg            0
# 9            9   ../input/train_images/video_0/9.jpg            0
# 10          10  ../input/train_images/video_0/10.jpg            0
# 11          11  ../input/train_images/video_0/11.jpg            0
# 12          12  ../input/train_images/video_0/12.jpg            0
# ...

# %%
df[df["kfold"] == 0]
# Out:
#        Unnamed: 0                                    path  int_nr_COTS  \
# 0               0     ../input/train_images/video_0/0.jpg            0
# 1               1     ../input/train_images/video_0/1.jpg            0
# 2               2     ../input/train_images/video_0/2.jpg            0
# 3               3     ../input/train_images/video_0/3.jpg            0
# 4               4     ../input/train_images/video_0/4.jpg            0
# 5               5     ../input/train_images/video_0/5.jpg            0
# 6               6     ../input/train_images/video_0/6.jpg            0
# 7               7     ../input/train_images/video_0/7.jpg            0
# 8               8     ../input/train_images/video_0/8.jpg            0
# 9               9     ../input/train_images/video_0/9.jpg            0
# 10             10    ../input/train_images/video_0/10.jpg            0
# 11             11    ../input/train_images/video_0/11.jpg            0
# ...

# %%
df[df["kfold"] == 1]
# Out:
#       Unnamed: 0                                    path  int_nr_COTS  \
# 21            21    ../input/train_images/video_0/21.jpg            1
# 22            22    ../input/train_images/video_0/22.jpg            1
# 23            23    ../input/train_images/video_0/23.jpg            1
# 24            24    ../input/train_images/video_0/24.jpg            1
# 25            25    ../input/train_images/video_0/25.jpg            1
# 37            37    ../input/train_images/video_0/37.jpg            2
# 38            38    ../input/train_images/video_0/38.jpg            2
# 202          202   ../input/train_images/video_0/202.jpg            0
# 203          203   ../input/train_images/video_0/203.jpg            0
# 204          204   ../input/train_images/video_0/204.jpg            0
# 205          205   ../input/train_images/video_0/205.jpg            0
# 206          206   ../input/train_images/video_0/206.jpg            0
# ...
